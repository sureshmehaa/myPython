# %% [markdown]
# # I am  going to show you how to filter RDD and dataframe using its row numbers

# %%
# %fs ls /FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Download_Data___STOCK_US_XNYS_WMT.csv</td><td>Download_Data___STOCK_US_XNYS_WMT.csv</td><td>1390</td></tr><tr><td>dbfs:/FileStore/tables/VS14MORT_txt.gz</td><td>VS14MORT_txt.gz</td><td>93093001</td></tr><tr><td>dbfs:/FileStore/tables/employee-1.txt</td><td>employee-1.txt</td><td>1023</td></tr><tr><td>dbfs:/FileStore/tables/employee.csv</td><td>employee.csv</td><td>28031</td></tr><tr><td>dbfs:/FileStore/tables/employee.txt</td><td>employee.txt</td><td>1023</td></tr><tr><td>dbfs:/FileStore/tables/international_migration_March_2021_estimated_migration_by_age_sex.csv</td><td>international_migration_March_2021_estimated_migration_by_age_sex.csv</td><td>4464659</td></tr><tr><td>dbfs:/FileStore/tables/test-1.csv</td><td>test-1.csv</td><td>335</td></tr><tr><td>dbfs:/FileStore/tables/test-2.csv</td><td>test-2.csv</td><td>335</td></tr><tr><td>dbfs:/FileStore/tables/test.csv</td><td>test.csv</td><td>335</td></tr><tr><td>dbfs:/FileStore/tables/test.xml</td><td>test.xml</td><td>292</td></tr><tr><td>dbfs:/FileStore/tables/userdata1.parquet</td><td>userdata1.parquet</td><td>113629</td></tr><tr><td>dbfs:/FileStore/tables/users.avro</td><td>users.avro</td><td>334</td></tr></tbody></table></div>

# %%
rdd = sc.textFile("dbfs:/FileStore/tables/employee.txt")

# %%
rdd.count()
# Out:
# Out[4]: 21

# %%
rdd.take(3)
# Out:
# Out[5]: ['Emp_id,Last_name,designation,job_id,hire_date,base_salary,commission,increment_pct',
#  '7369,SMITH,CLERK,7902,17-Dec-80,800,\\000,20',
#  '7499,ALLEN,SALESMAN,7698,20-Feb-81,1600,300,30']

# %%
rdd=rdd.zipWithIndex()

# %%
rdd.take(3)
# Out:
# Out[7]: [('Emp_id,Last_name,designation,job_id,hire_date,base_salary,commission,increment_pct',
#   0),
#  ('7369,SMITH,CLERK,7902,17-Dec-80,800,\\000,20', 1),
#  ('7499,ALLEN,SALESMAN,7698,20-Feb-81,1600,300,30', 2)]

# %% [markdown]
# # you can see row number in each row from the above output.

# %%
rdd.filter(lambda x:x[1]==11).collect()
# Out:
# Out[8]: [('7876,ADAMS,CLERK,7788,12-Jan-83,1100,\\000,20', 11)]

# %% [markdown]
# # we have filter out 11th row from an RDD

# %% [markdown]
# # lets filter the data frame

# %%
df = spark.read.csv("dbfs:/FileStore/tables/employee.txt", header=True,inferSchema=True)

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_id</th><th>Last_name</th><th>designation</th><th>job_id</th><th>hire_date</th><th>base_salary</th><th>commission</th><th>increment_pct</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>17-Dec-80</td><td>800</td><td>\000</td><td>20</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>20-Feb-81</td><td>1600</td><td>300</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>22-Feb-81</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>02-Apr-81</td><td>2975</td><td>\000</td><td>20</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>28-Sep-81</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>01-May-81</td><td>2850</td><td>\000</td><td>30</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>09-Jun-81</td><td>2450</td><td>\000</td><td>10</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>09-Dec-82</td><td>3000</td><td>\000</td><td>20</td></tr><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>\000</td><td>17-Nov-81</td><td>5000</td><td>\000</td><td>10</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>08-Sep-81</td><td>1500</td><td>0</td><td>30</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>12-Jan-83</td><td>1100</td><td>\000</td><td>20</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>03-Dec-81</td><td>950</td><td>\000</td><td>30</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>03-Dec-81</td><td>3000</td><td>\000</td><td>20</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>23-Jan-82</td><td>1300</td><td>\000</td><td>10</td></tr><tr><td>7333</td><td>ALAN</td><td>CLERK</td><td>7783</td><td>30-Apr-80</td><td>1600</td><td>\000</td><td>10</td></tr><tr><td>7342</td><td>MAYIM</td><td>ANALYST</td><td>7566</td><td>30-Apr-80</td><td>3150</td><td>\000</td><td>10</td></tr><tr><td>7975</td><td>KUNAL</td><td>SALESMAN</td><td>7698</td><td>15-Sep-82</td><td>1300</td><td>250</td><td>20</td></tr><tr><td>7432</td><td>FROST</td><td>MANAGER</td><td>7839</td><td>15-Sep</td><td>2600</td><td>\000</td><td>30</td></tr><tr><td>7916</td><td>GILL</td><td>CLERK</td><td>7782</td><td>19-Jan-81</td><td>800</td><td>\000</td><td>10</td></tr><tr><td>7730</td><td>NAOMI</td><td>CLERK</td><td>7902</td><td>01-Jan-80</td><td>1000</td><td>\000</td><td>20</td></tr></tbody></table></div>

# %% [markdown]
# lets filter out the rows using row_number function

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number

# %%
spec=Window.orderBy("Emp_ID")

# %%
df=df.withColumn("row_num",row_number().over(spec))

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_id</th><th>Last_name</th><th>designation</th><th>job_id</th><th>hire_date</th><th>base_salary</th><th>commission</th><th>increment_pct</th><th>row_num</th></tr></thead><tbody><tr><td>7333</td><td>ALAN</td><td>CLERK</td><td>7783</td><td>30-Apr-80</td><td>1600</td><td>\000</td><td>10</td><td>1</td></tr><tr><td>7342</td><td>MAYIM</td><td>ANALYST</td><td>7566</td><td>30-Apr-80</td><td>3150</td><td>\000</td><td>10</td><td>2</td></tr><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>17-Dec-80</td><td>800</td><td>\000</td><td>20</td><td>3</td></tr><tr><td>7432</td><td>FROST</td><td>MANAGER</td><td>7839</td><td>15-Sep</td><td>2600</td><td>\000</td><td>30</td><td>4</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>20-Feb-81</td><td>1600</td><td>300</td><td>30</td><td>5</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>22-Feb-81</td><td>1250</td><td>500</td><td>30</td><td>6</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>02-Apr-81</td><td>2975</td><td>\000</td><td>20</td><td>7</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>28-Sep-81</td><td>1250</td><td>1400</td><td>30</td><td>8</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>01-May-81</td><td>2850</td><td>\000</td><td>30</td><td>9</td></tr><tr><td>7730</td><td>NAOMI</td><td>CLERK</td><td>7902</td><td>01-Jan-80</td><td>1000</td><td>\000</td><td>20</td><td>10</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>09-Jun-81</td><td>2450</td><td>\000</td><td>10</td><td>11</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>09-Dec-82</td><td>3000</td><td>\000</td><td>20</td><td>12</td></tr><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>\000</td><td>17-Nov-81</td><td>5000</td><td>\000</td><td>10</td><td>13</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>08-Sep-81</td><td>1500</td><td>0</td><td>30</td><td>14</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>12-Jan-83</td><td>1100</td><td>\000</td><td>20</td><td>15</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>03-Dec-81</td><td>950</td><td>\000</td><td>30</td><td>16</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>03-Dec-81</td><td>3000</td><td>\000</td><td>20</td><td>17</td></tr><tr><td>7916</td><td>GILL</td><td>CLERK</td><td>7782</td><td>19-Jan-81</td><td>800</td><td>\000</td><td>10</td><td>18</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>23-Jan-82</td><td>1300</td><td>\000</td><td>10</td><td>19</td></tr><tr><td>7975</td><td>KUNAL</td><td>SALESMAN</td><td>7698</td><td>15-Sep-82</td><td>1300</td><td>250</td><td>20</td><td>20</td></tr></tbody></table></div>

# %% [markdown]
# # you can see row number column from the above df

# %%
df.filter(df.row_num==11).show()
# Out:
# +------+---------+-----------+------+---------+-----------+----------+-------------+-------+
# |Emp_id|Last_name|designation|job_id|hire_date|base_salary|commission|increment_pct|row_num|
# +------+---------+-----------+------+---------+-----------+----------+-------------+-------+
# |  7782|    CLARK|    MANAGER|  7839|09-Jun-81|       2450|      \000|           10|     11|
# +------+---------+-----------+------+---------+-----------+----------+-------------+-------+

# %% [markdown]
# # thats all my friends. Thanks a lot for watching this video.
